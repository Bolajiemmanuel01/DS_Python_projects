# %%
import pandas as pd

# %%
dataset = pd.read_csv("data/Public_School_Characteristics_-_Current.csv")
dataset.head()
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_47040\3491001884.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv("data/Public_School_Characteristics_-_Current.csv")
#               X             Y  OBJECTID      NCESSCH   SURVYEAR STABR   LEAID  \
# 0 -9.596430e+06  4.063794e+06         1  10000500870  2021-2022    AL  100005
# 1 -9.596286e+06  4.064064e+06         2  10000500871  2021-2022    AL  100005
# 2 -9.597978e+06  4.065559e+06         3  10000500879  2021-2022    AL  100005
# 3 -9.598168e+06  4.062784e+06         4  10000500889  2021-2022    AL  100005
# 4 -9.594994e+06  4.067782e+06         5  10000501616  2021-2022    AL  100005
#
#   ST_LEAID          LEA_NAME                           SCH_NAME  ...  HIALF  \
# 0   AL-101  Albertville City          Albertville Middle School  ...  246.0
# 1   AL-101  Albertville City            Albertville High School  ...  424.0
# ...

# %%
dataset.shape
# Out:
# (101278, 81)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101278 entries, 0 to 101277
# Data columns (total 81 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   X                 101278 non-null  float64
#  1   Y                 101278 non-null  float64
#  2   OBJECTID          101278 non-null  int64
#  3   NCESSCH           101278 non-null  int64
#  4   SURVYEAR          101278 non-null  object
#  5   STABR             101278 non-null  object
#  6   LEAID             101278 non-null  int64
#  7   ST_LEAID          101278 non-null  object
#  8   LEA_NAME          101278 non-null  object
#  9   SCH_NAME          101278 non-null  object
#  10  LSTREET1          101275 non-null  object
#  11  LSTREET2          572 non-null     object
#  12  LCITY             101278 non-null  object
#  13  LSTATE            101278 non-null  object
#  14  LZIP              101278 non-null  int64
#  15  LZIP4             101278 non-null  object
# ...

# %%
dataset.nunique()
# Out:
# X            90477
# Y            88599
# OBJECTID    101278
# NCESSCH     101278
# SURVYEAR         1
#              ...
# WHALM         1033
# WHALF         1001
# WH            1788
# LATCOD       88599
# LONCOD       90477
# Length: 81, dtype: int64
